# %%
import pandas as pd
df = pd.read_csv('Salary_Data.csv')
print(df.head())
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
X = df. iloc[ :, :- 1].values
y = df. iloc[:, 1].values

# %%
import matplotlib.pyplot as plt
plt.scatter(X, y, color = "red")
plt.xlabel('Years Experience')
plt.ylabel('Salary')
plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state=29)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
a = regressor.intercept_
b = regressor.coef_[0]
print("Estimated model intercept, a:", a)
print("Estimated model slope, b:", b)
print(f"ŷ = {a:.2f} + {b:.2f}x")
# Out:
# Estimated model intercept, a: 26401.461669402415
# Estimated model slope, b: 9337.872905864879
# ŷ = 26401.46 + 9337.87x

# %%
y_pred = regressor.predict(X_test)
y_pred
# Out:
# array([ 74024.61348931,  89898.99742928,  81494.91181401, 102972.01949749,
#        116045.04156571,  45077.20748113])

# %%
from sklearn.metrics import r2_score
score=r2_score(y_test,y_pred)
score
# Out:
# 0.9467172742609804

# %%
plt.scatter(X_train, y_train, color = 'red')
plt.plot(X_train, regressor.predict(X_train), color = 'blue')

# %%
plt.scatter(X_test, y_test, color = 'red')
plt.plot(X_train, regressor.predict(X_train), color = 'blue')
plt.title('Salary vs Experience (Test set)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()

# %%
df2 = pd.read_csv('multiple_linear_regression_dataset.csv')
print(df2.head())
# Out:
#    age  experience  income
# 0   25           1   30450
# 1   30           3   35670
# 2   47           2   31580
# 3   32           5   40130
# 4   43          10   47830

# %%
X2 = df2.iloc[:, :-1]
y2 = df2.iloc[:, 2]

# %%
X_train2, X_test2, y_train2, y_test2 = train_test_split(X2, y2, test_size = 0.2, random_state=29)

# %%
regressor = LinearRegression()
regressor.fit(X_train2, y_train2)
# Out:
# LinearRegression()

# %%
y_pred2 = regressor.predict(X_test2)
print(y_pred2)
# Out:
# [36654.1067363  46102.07759391 40201.43517489 31139.89749137]

# %%
a_ = regressor.intercept_
b1 = regressor.coef_[0]
b2 = regressor.coef_[1]
print("Estimated model intercept, a:", a_)
print("Estimated model slope, b1:", b1)
print("Estimated model slope, b2:", b2)
print(f"ŷ = {a:.2f} {b1:.2f}x1 + {b2:.2f}x2")
# Out:
# Estimated model intercept, a: 31201.79084897794
# Estimated model slope, b1: -96.60829352149992
# Estimated model slope, b2: 2160.0973933827536
# ŷ = 26401.46 -96.61x1 + 2160.10x2

# %%
score2=r2_score(y_test2,y_pred2)
score2
# Out:
# 0.9764147385208979

# %%
#Tugas No 1
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

df = pd.read_csv('rounded_hours_student_scores.csv')
X = df.iloc[:, :-1].values
y = df.iloc[:, 1].values

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=29)
regressor = LinearRegression()
regressor.fit(X_train, y_train)

y_pred = regressor.predict(X_test)
print("Hasil Prediksi Score:", y_pred)
# Out:
# Hasil Prediksi Score: [49.95449381 48.60857576 43.03262954 40.53306744 47.83947973 40.91761545
#  50.72358984 41.30216347 51.87723389 53.22315194 46.30128767 45.53219163]

# %%
#Tugas No 2
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

df = pd.read_csv('Marketing_Data.csv')
X = df.iloc[:, :-1].values
y = df.iloc[:, -1].values

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=29)
regressor = LinearRegression()
regressor.fit(X_train, y_train)

y_pred = regressor.predict(X_test)
print("Hasil Prediksi Sales:", y_pred)
# Out:
# Hasil Prediksi Sales: [22.07788504  9.70162953 20.70327762 17.09623742 17.25559598 24.29338944
#  22.66535771 13.66252943 16.52354192 16.5187185  23.0672181   5.41542283
#  20.62547692 10.31775585 18.7662409   8.30807923 23.43527001 28.05389209
#  22.26870266 16.64057351 17.01042299  7.87702568 15.3077115  15.24101138
#   6.44036921 12.32027331 24.5721646   5.41916636  7.44604231 10.51282424
#  11.42453648 19.85745164 29.04926557  6.85728469 18.50877297]
